# %% [markdown]
# Importamos las librerias que nos hacen falta

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from collections import Counter
from scipy.spatial import distance

# %% [markdown]
# Vamos a crear un dataset con el archivo csv 'movies-dataset'

# %%
df_peliculas = pd.read_csv ('..\Proyecto individual Henry\Data\movies_dataset (1).csv')
# Out:
# C:\Users\Andrea\AppData\Local\Temp\ipykernel_13920\270986259.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_peliculas = pd.read_csv ('..\Proyecto individual Henry\Data\movies_dataset (1).csv')

# %% [markdown]
# Vemos el contenido del dataset

# %%
df_peliculas.head(15)
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   False                                                NaN  16000000
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 7   False                                                NaN         0
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 11  False                                                NaN         0
# ...

# %% [markdown]
# Vamos a ver como la información del df_peliculas

# %%
df_peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %% [markdown]
# Vamos a rellenar los nulos de las columna revenue por cero.

# %%
df_peliculas['revenue'].fillna(0)
# Out:
# 0        373554033.0
# 1        262797249.0
# 2                0.0
# 3         81452156.0
# 4         76578911.0
#             ...
# 45461            0.0
# 45462            0.0
# 45463            0.0
# 45464            0.0
# 45465            0.0
# Name: revenue, Length: 45466, dtype: float64

# %% [markdown]
# Vamos a rellenar los nulos de las columna budget por cero.

# %%
df_peliculas['budget'].replace('NaN',0)
# Out:
# 0        30000000
# 1        65000000
# 2               0
# 3        16000000
# 4               0
#            ...
# 45461           0
# 45462           0
# 45463           0
# 45464           0
# 45465           0
# Name: budget, Length: 45466, dtype: object

# %% [markdown]
# Eliminamos valores nulos de la columna release_date

# %%
df_peliculas = df_peliculas.dropna(subset=['release_date'])

# %% [markdown]
# Vemos la columna release_date del df_peliculas

# %%
df_peliculas['release_date']
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 45460    1991-05-13
# 45462    2011-11-17
# 45463    2003-08-01
# 45464    1917-10-21
# 45465    2017-06-09
# Name: release_date, Length: 45379, dtype: object

# %% [markdown]
# Agregamos el año de la fecha de extreno en una columna release_year

# %%
df_peliculas['release_year']= df_peliculas['release_date'].str.slice(0,4)

# %% [markdown]
# Vemos la columna release_year

# %%
df_peliculas['release_year']
# Out:
# 0        1995
# 1        1995
# 2        1995
# 3        1995
# 4        1995
#          ...
# 45460    1991
# 45462    2011
# 45463    2003
# 45464    1917
# 45465    2017
# Name: release_year, Length: 45379, dtype: object

# %% [markdown]
# Vemos la informacion del dataset df_peliculas

# %%
df_peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45379 entries, 0 to 45465
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45379 non-null  object
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45379 non-null  object
#  3   genres                 45379 non-null  object
#  4   homepage               7769 non-null   object
#  5   id                     45379 non-null  object
#  6   imdb_id                45365 non-null  object
#  7   original_language      45368 non-null  object
#  8   original_title         45379 non-null  object
#  9   overview               44438 non-null  object
#  10  popularity             45377 non-null  object
#  11  poster_path            45040 non-null  object
#  12  production_companies   45379 non-null  object
#  13  production_countries   45379 non-null  object
# ...

# %% [markdown]
# Importamos datetime de datetime

# %%
from datetime import datetime

# %% [markdown]
# Convertimos la columna release_date en tipo de dato fecha

# %%
df_peliculas['release_date']= pd.to_datetime(df_peliculas['release_date'], errors='coerce')

# %% [markdown]
# Volvemos a ver la informacion df_peliculas donde figura datetime como tipo de dato de la columna release_date

# %%
df_peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45379 entries, 0 to 45465
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45379 non-null  object
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45379 non-null  object
#  3   genres                 45379 non-null  object
#  4   homepage               7769 non-null   object
#  5   id                     45379 non-null  object
#  6   imdb_id                45365 non-null  object
#  7   original_language      45368 non-null  object
#  8   original_title         45379 non-null  object
#  9   overview               44438 non-null  object
#  10  popularity             45377 non-null  object
#  11  poster_path            45040 non-null  object
#  12  production_companies   45379 non-null  object
#  13  production_countries   45379 non-null  object
# ...

# %% [markdown]
# Cambiamos los nulos por cero de la columna release_year

# %%
df_peliculas['release_year']= df_peliculas['release_year'].replace('NaN', 0)
df_peliculas['release_year']
# Out:
# 0        1995
# 1        1995
# 2        1995
# 3        1995
# 4        1995
#          ...
# 45460    1991
# 45462    2011
# 45463    2003
# 45464    1917
# 45465    2017
# Name: release_year, Length: 45379, dtype: object

# %% [markdown]
# Vemos los últimos 15 datos

# %%
df_peliculas.head(-15)
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45445  False                                                NaN         0
# 45446  False                                                NaN         0
# 45447  False                                                NaN         0
# 45448  False                                                NaN         0
# 45449  False                                                NaN         0
#
#                                                   genres  \
# ...

# %% [markdown]
# Eliminamos nulos de la columna release_year

# %%
df_peliculas=df_peliculas.dropna(subset=['release_year'])

# %% [markdown]
# Vemos los tipos de datos del dataset

# %%
df_peliculas.dtypes
# Out:
# adult                            object
# belongs_to_collection            object
# budget                           object
# genres                           object
# homepage                         object
# id                               object
# imdb_id                          object
# original_language                object
# original_title                   object
# overview                         object
# popularity                       object
# poster_path                      object
# production_companies             object
# production_countries             object
# release_date             datetime64[ns]
# revenue                         float64
# runtime                         float64
# spoken_languages                 object
# status                           object
# tagline                          object
# title                            object
# video                            object
# vote_average                    float64
# ...

# %% [markdown]
# Cambiar los valores no finitos de la columna release_year por cero

# %%
df_peliculas['release_year']= df_peliculas['release_year'].fillna(0)

# %%
df_peliculas['release_year']
# Out:
# 0        1995
# 1        1995
# 2        1995
# 3        1995
# 4        1995
#          ...
# 45460    1991
# 45462    2011
# 45463    2003
# 45464    1917
# 45465    2017
# Name: release_year, Length: 45379, dtype: object

# %% [markdown]
# Cambio el tipo de dato de la columna release_year de float a int

# %%
df_peliculas['release_year']=df_peliculas['release_year'].astype(int)

# %% [markdown]
# Eliminamos nulos de la columna 'title'

# %%
df_peliculas= df_peliculas.dropna(subset=['title'])

# %% [markdown]
# Vemos los 3 primeros datos del dataset

# %%
df_peliculas.head(3)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
#
#      original_title                                           overview  ...  \
# 0         Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# ...

# %% [markdown]
# Volvemos a ver la información

# %%
df_peliculas.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %% [markdown]
# Vemos los duplicados

# %%
new_duplicate= df_peliculas[df_peliculas.duplicated('id')]
print(new_duplicate)
# Out:
#        adult                              belongs_to_collection    budget  \
# 1465   False                                                NaN         0
# 9165   False                                                NaN         0
# 9327   False                                                NaN         0
# 12066  False                                                NaN   1600000
# 13375  False                                                NaN         0
# 15074  False                                                NaN         4
# 15765  False                                                NaN      2500
# 16764  False                                                NaN         0
# 20843  False                                                NaN  40000000
# 20899  False                                                NaN         0
# 21116  False                                                NaN         0
# 21165  False                                                NaN         0
# ...

# %% [markdown]
# Eliminamos los duplicados teniendo en cuenta la columna id

# %%
df_peliculas.drop_duplicates(subset=['id'], inplace=True)

# %% [markdown]
# Vemos la informacion del df_peliculas nuevamente

# %%
df_peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45346 entries, 0 to 45465
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45346 non-null  object
#  1   belongs_to_collection  4485 non-null   object
#  2   budget                 45346 non-null  object
#  3   genres                 45346 non-null  object
#  4   homepage               7761 non-null   object
#  5   id                     45346 non-null  object
#  6   imdb_id                45332 non-null  object
#  7   original_language      45335 non-null  object
#  8   original_title         45346 non-null  object
#  9   overview               44405 non-null  object
#  10  popularity             45346 non-null  object
#  11  poster_path            45007 non-null  object
#  12  production_companies   45346 non-null  object
#  13  production_countries   45346 non-null  object
# ...

# %% [markdown]
# Vemos solo los tipos de la columnas

# %%
df_peliculas.dtypes
# Out:
# adult                            object
# belongs_to_collection            object
# budget                           object
# genres                           object
# homepage                         object
# id                               object
# imdb_id                          object
# original_language                object
# original_title                   object
# overview                         object
# popularity                       object
# poster_path                      object
# production_companies             object
# production_countries             object
# release_date             datetime64[ns]
# revenue                         float64
# runtime                         float64
# spoken_languages                 object
# status                           object
# tagline                          object
# title                            object
# video                            object
# vote_average                    float64
# ...

# %% [markdown]
# Vamos a cambiar el tipo de dato de la columna budget de objet a float.

# %%
df_peliculas['budget']= pd.to_numeric(df_peliculas['budget'], errors='coerce')

# %% [markdown]
# Vamos a crear la columna return dividiendo la columna revenue en budget

# %%
df_peliculas['return'] = df_peliculas['revenue']/df_peliculas['budget']

# %% [markdown]
# En la columna return vamos a remplazar valores nulos por ceros

# %%
df_peliculas['return']= df_peliculas['return'].fillna(0)

# %%
df_peliculas['return']
# Out:
# 0        12.451801
# 1         4.043035
# 2         0.000000
# 3         5.090760
# 4              inf
#            ...
# 45460     0.000000
# 45462     0.000000
# 45463     0.000000
# 45464     0.000000
# 45465     0.000000
# Name: return, Length: 45346, dtype: float64

# %% [markdown]
# Creo un df_collection copiando la columan belongs_to_collection

# %%
df_collection = df_peliculas[['belongs_to_collection']].copy()

# %%
import json
from pandas import json_normalize

# %%
print(df_collection)
# Out:
#                                    belongs_to_collection
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                    NaN
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                    NaN
# 4      {'id': 96871, 'name': 'Father of the Bride Col...
# ...                                                  ...
# 45460                                                NaN
# 45462                                                NaN
# 45463                                                NaN
# 45464                                                NaN
# 45465                                                NaN
#
# [45346 rows x 1 columns]

# %% [markdown]
# Eliminamos nulos de la columna belongs_to_collection

# %%
df_collection = df_collection.dropna(subset=['belongs_to_collection'])

# %% [markdown]
# Accedemos a los valores de los diccionarios. Vamos a crear una columna id en df_collection

# %%
df_collection['id']=df_collection['belongs_to_collection'].apply(lambda x : x[7:13])

# %% [markdown]
# Vamos a remplazar valor para limpiar la columna id

# %%
df_collection['id']= df_collection['id'].replace(',','', regex=True)
df_collection['id']= df_collection['id'].replace(' ','', regex=True)
df_collection['id']= df_collection['id'].replace("'","", regex=True)

# %% [markdown]
# Creamos una columna name en df_collection

# %%
df_collection['name']=df_collection['belongs_to_collection'].apply(lambda x: x[20:])

# %% [markdown]
# Limpiamos esa columna name del df_collection

# %%
df_collection['name']= df_collection['name'].str.split(',',expand=True)[0]
df_collection['name']= df_collection['name'].str.replace(': ','')
df_collection['name']= df_collection['name'].str.replace("''","'")

# %% [markdown]
# Creamos otra columna poster_path en df_collection

# %%
df_collection['poster_path']=df_collection['belongs_to_collection'].apply(lambda x: x[57:])

# %%
df_collection['poster_path']
# Out:
# 0        h': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backd...
# 2        er_path': '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg', ...
# 4        poster_path': '/nts4iOmNnq7GNicycMJ9pSAn204.jp...
# 9        ': '/HORpg5CSkmeQlAolx3bKMrKgfi.jpg', 'backdro...
# 12        '/w0ZgH6Lgxt2bQYnf1ss74UvYftm.jpg', 'backdrop...
#                                ...
# 45355    path': '/2P0HNrYgKDvirV8RCdT1rBSJdbJ.jpg', 'ba...
# 45358    path': '/2P0HNrYgKDvirV8RCdT1rBSJdbJ.jpg', 'ba...
# 45369    path': '/2P0HNrYgKDvirV8RCdT1rBSJdbJ.jpg', 'ba...
# 45371          'poster_path': None, 'backdrop_path': None}
# 45382    th': '/yf9Eod9ANXyHTzDpAxz9ezgvlL4.jpg', 'back...
# Name: poster_path, Length: 4485, dtype: object

# %% [markdown]
# Limpiamos esa columna poster_path

# %%
df_collection['poster_path']= df_collection['poster_path'].str.replace("'poster_path':'",'')

# %% [markdown]
# Elimino todo lo que esta antes del espacio

# %%
df_collection['poster_path']= df_collection['poster_path'].str.split(" ",expand=True)[1]

# %% [markdown]
# Elimino de la columna poster_path todo lo que esta despues de la coma

# %%
df_collection['poster_path']= df_collection['poster_path'].str.split("\,",expand=True)[0]

# %% [markdown]
# Creamos un columna backdrop_path en el df_collection

# %%
df_collection['backdrop_path']=df_collection['belongs_to_collection'].apply(lambda x: x[110:])

# %% [markdown]
# Elimino de la columna backdrop_path todo lo que esta antes del espacio.

# %%
df_collection['backdrop_path']= df_collection['backdrop_path'].str.split(" ",expand=True)[1]

# %% [markdown]
# Elimino de la columna backdrop_path la llave.

# %%
df_collection['backdrop_path']= df_collection['backdrop_path'].str.replace('}','')
# Out:
# C:\Users\Andrea\AppData\Local\Temp\ipykernel_13920\1380748080.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_collection['backdrop_path']= df_collection['backdrop_path'].str.replace('}','')

# %% [markdown]
# Vemos como quedo el df_collection

# %%
df_collection
# Out:
#                                    belongs_to_collection      id  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...   10194
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...  119050
# 4      {'id': 96871, 'name': 'Father of the Bride Col...   96871
# 9      {'id': 645, 'name': 'James Bond Collection', '...     645
# 12     {'id': 117693, 'name': 'Balto Collection', 'po...  117693
# ...                                                  ...     ...
# 45355  {'id': 37261, 'name': 'The Carry On Collection...   37261
# 45358  {'id': 37261, 'name': 'The Carry On Collection...   37261
# 45369  {'id': 37261, 'name': 'The Carry On Collection...   37261
# 45371  {'id': 477208, 'name': 'DC Super Hero Girls Co...  477208
# 45382  {'id': 200641, 'name': 'Red Lotus Collection',...  200641
#
#                                    name                         poster_path  \
# 0                'Toy Story Collection'  '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg'
# ...

# %% [markdown]
# Eliminamos la columna belongs_to_collection del df_collection

# %%
df_collection= df_collection.drop('belongs_to_collection', axis=1)

# %% [markdown]
# Mostramos nuevamente el df_collection

# %%
df_collection
# Out:
#            id                              name  \
# 0       10194            'Toy Story Collection'
# 2      119050       'Grumpy Old Men Collection'
# 4       96871  'Father of the Bride Collection'
# 9         645           'James Bond Collection'
# 12     117693                'Balto Collection'
# ...       ...                               ...
# 45355   37261         'The Carry On Collection'
# 45358   37261         'The Carry On Collection'
# 45369   37261         'The Carry On Collection'
# 45371  477208  'DC Super Hero Girls Collection'
# 45382  200641            'Red Lotus Collection'
#
#                               poster_path                       backdrop_path
# 0      '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg'  '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'
# 2      '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg'  '/hypTnLot2z8wpFS7qwsQHW1uV8u.jpg'
# 4      '/nts4iOmNnq7GNicycMJ9pSAn204.jpg'  '/7qwE57OVZmMJChBpLEbJEmzUydk.jpg'
# ...

# %%
df_collection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4485 entries, 0 to 45382
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             4485 non-null   object
#  1   name           4485 non-null   object
#  2   poster_path    4485 non-null   object
#  3   backdrop_path  3542 non-null   object
# dtypes: object(4)
# memory usage: 175.2+ KB

# %%
df_collection.to_csv('collection.csv', index = False)

# %% [markdown]
# Procedemos a eliminar columnas: 'adult','homepage','imdb_id','original_title','video' y 'poster_path')

# %%
df_peliculas=df_peliculas.drop('adult', axis=1)

# %%
df_peliculas=df_peliculas.drop('homepage', axis=1)
df_peliculas=df_peliculas.drop('imdb_id', axis=1)
df_peliculas=df_peliculas.drop('original_title', axis=1)
df_peliculas=df_peliculas.drop('video', axis=1)

# %%
df_peliculas=df_peliculas.drop('poster_path', axis=1)

# %%
df_peliculas
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45460                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %%
df_peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45346 entries, 0 to 45465
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4485 non-null   object
#  1   budget                 45346 non-null  int64
#  2   genres                 45346 non-null  object
#  3   id                     45346 non-null  object
#  4   original_language      45335 non-null  object
#  5   overview               44405 non-null  object
#  6   popularity             45346 non-null  object
#  7   production_companies   45346 non-null  object
#  8   production_countries   45346 non-null  object
#  9   release_date           45346 non-null  datetime64[ns]
#  10  revenue                45346 non-null  float64
#  11  runtime                45100 non-null  float64
#  12  spoken_languages       45346 non-null  object
#  13  status                 45266 non-null  object
# ...

# %% [markdown]
# Vamos a aplicar ast.literal_eval a la columna genres

# %%
import ast
df_peliculas['genres']= df_peliculas['genres'].apply(ast.literal_eval)

# %% [markdown]
# La columna genres en df_peliculas solo va a contener el nombre del genero

# %%
df_peliculas['genres']= df_peliculas['genres'].apply(lambda x :[d['name'] for d in x])

# %%
df_peliculas['genres']
# Out:
# 0         [Animation, Comedy, Family]
# 1        [Adventure, Fantasy, Family]
# 2                   [Romance, Comedy]
# 3            [Comedy, Drama, Romance]
# 4                            [Comedy]
#                      ...
# 45460        [Drama, Action, Romance]
# 45462                         [Drama]
# 45463       [Action, Drama, Thriller]
# 45464                              []
# 45465                              []
# Name: genres, Length: 45346, dtype: object

# %%
df_peliculas
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45460                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                              genres      id original_language  \
# 0       [Animation, Comedy, Family]     862                en
# ...

# %% [markdown]
# Vamos a dejar solo el nombre en la columna production_companies

# %%
df_peliculas['production_companies']=df_peliculas['production_companies'].apply(ast.literal_eval)

# %%
df_peliculas['production_companies']=df_peliculas['production_companies'].apply(lambda x: [d['name']for d in x])

# %% [markdown]
# Vamos a dejar solo el nombre en la columna production_countries

# %%
df_peliculas['production_countries']=df_peliculas['production_countries'].apply(ast.literal_eval)

# %%
df_peliculas['production_countries']=df_peliculas['production_countries'].apply(lambda x: [d['name']for d in x])

# %%
df_peliculas
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45460                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                              genres      id original_language  \
# 0       [Animation, Comedy, Family]     862                en
# ...

# %%
df_peliculas.to_csv('peliculas.csv', index=False)

# %% [markdown]
# Vamos a crear otro dataset con los datos de credits

# %%
df_credits =pd.read_csv('..\Proyecto individual Henry\Data\credits (1).csv')

# %% [markdown]
# Vemos algunos datos del dataset

# %%
df_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
df_crew= df_credits.copy()

# %%
df_crew =df_crew.drop('cast', axis=1)

# %%
df_crew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   crew    45476 non-null  object
#  1   id      45476 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 710.7+ KB

# %% [markdown]
# Convierto la cadena de texto en lista de diccionario utilizando la función ast.literal_eval del modulo ast

# %%
import ast
df_crew['crew']= df_crew['crew'].apply(ast.literal_eval)

# %% [markdown]
# Creo una nueva columna en df_crew llamada job_crew donde cada elemento es una lista de valores de 'job'

# %%
df_crew['job_crew']= df_crew['crew'].apply(lambda x :[d['job'] for d in x])

# %% [markdown]
# Creo una nueva columna en df_crew llamada name_crew donde cada elemento es una lista de valores de 'name'

# %%
df_crew['name_crew']= df_crew['crew'].apply(lambda x :[d['name'] for d in x])

# %%
df_crew
# Out:
#                                                     crew      id  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...   31357
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...   11862
# ...                                                  ...     ...
# 45471  [{'credit_id': '5894a97d925141426c00818c', 'de...  439050
# 45472  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...  111109
# 45473  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...   67758
# 45474  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...  227506
# 45475  [{'credit_id': '593e676c92514105b702e68e', 'de...  461257
#
#                                                 job_crew  \
# 0      [Director, Screenplay, Screenplay, Screenplay,...
# 1      [Executive Producer, Screenplay, Original Musi...
# ...

# %% [markdown]
# Elimino la columna crew del df_crew

# %%
df_crew = df_crew.drop('crew', axis=1)

# %%
df_crew
# Out:
#            id                                           job_crew  \
# 0         862  [Director, Screenplay, Screenplay, Screenplay,...
# 1        8844  [Executive Producer, Screenplay, Original Musi...
# 2       15602    [Director, Characters, Writer, Sound Recordist]
# 3       31357  [Director, Screenplay, Producer, Producer, Pro...
# 4       11862  [Original Music Composer, Director of Photogra...
# ...       ...                                                ...
# 45471  439050  [Director, Producer, Camera Supervisor, Script...
# 45472  111109  [Director, Writer, Production Design, Music, E...
# 45473   67758  [Director, Screenplay, Screenplay, Original Mu...
# 45474  227506                               [Director, Producer]
# 45475  461257                                         [Director]
#
#                                                name_crew
# 0      [John Lasseter, Joss Whedon, Andrew Stanton, J...
# 1      [Larry J. Franco, Jonathan Hensleigh, James Ho...
# ...

# %%
df_crew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         45476 non-null  int64
#  1   job_crew   45476 non-null  object
#  2   name_crew  45476 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %% [markdown]
# Vemos los nulos

# %%
new_dupli= df_crew[df_crew.duplicated('id')]
print(new_dupli)
# Out:
#            id                                           job_crew  \
# 1465   105045                 [Director, Writer, Writer, Writer]
# 9165     5511  [Director of Photography, Producer, Screenplay...
# 9327    23305                         [Director, Writer, Writer]
# 12066   14788  [Director, Director of Photography, Editor, Wr...
# 13375  141971                                 [Director, Writer]
# 15074   22649  [Director of Photography, Costume Design, Art ...
# 15765   13209         [Director, Writer, Writer, Cinematography]
# 16764  141971                                 [Director, Writer]
# 20842   77221  [Screenplay, Original Music Composer, Director...
# 20898  109962               [Director, Theatre Play, Screenplay]
# 21115   84198                               [Director, Director]
# 21164  119916                                 [Author, Director]
# 21853  152795  [Producer, Casting, Novel, Producer, Music, Ci...
# ...

# %%
new_dupli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 1465 to 45275
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         44 non-null     int64
#  1   job_crew   44 non-null     object
#  2   name_crew  44 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ KB

# %% [markdown]
# Se creara una lista de nombre en los cuales job coicida con la palabra Director

# %%
df_director = df_crew[df_crew['job_crew'].apply (lambda x : 'Director'in x)]

# %%
director_names = df_director['name_crew'].tolist()

# %%
director_names
# Out:
# [['John Lasseter',
#   'Joss Whedon',
#   'Andrew Stanton',
#   'Joel Cohen',
#   'Alec Sokolow',
#   'Bonnie Arnold',
#   'Ed Catmull',
#   'Ralph Guggenheim',
#   'Steve Jobs',
#   'Lee Unkrich',
#   'Ralph Eggleston',
#   'Robert Gordon',
#   'Mary Helen Leasman',
#   'Kim Blanchette',
#   'Marilyn McCoppen',
#   'Randy Newman',
#   'Dale E. Grahn',
#   'Robin Cooper',
#   'John Lasseter',
#   'Pete Docter',
#   'Joe Ranft',
#   'Patsy Bouge',
#   'Norm DeCarlo',
#   'Ash Brannon',
#   'Randy Newman',
#   'Roman Figun',
#   'Don Davis',
#   'James Flamberg',
#   'Mary Beth Smith',
#   'Rick Mackay',
#   'Susan Bradley',
#   'William Reeves',
#   'Randy Newman',
#   'Andrew Stanton',
#   'Pete Docter',
#   'Gary Rydstrom',
#   'Karen Robert Jackson',
#   'Chris Montan',
#   'Rich Quade',
#   'Michael Berenstein',
#   'Colin Brady',
#   'Davey Crockett Feiten',
#   'Angie Glocka',
#   'Rex Grignon',
#   'Tom K. Gurney',
#   'Jimmy Hayward',
#   'Hal T. Hickel',
#   'Karen Kiser',
# ...

# %% [markdown]
# Queremos saber cuantos directores son para lo cual realizamos lo siguente

# %%
numero_director = len(director_names)

# %%
numero_director
# Out:
# 44589

# %% [markdown]
# Luego de haber realizado ETL vamos a proceder a relizar el Analisis Exploratorio de los datos (EDA)

# %% [markdown]
# Teniendo en cuenta que lo que queremos obtener es un sistema de recomendación de peliculas vamos a
# empezar con el EDA

# %% [markdown]
# ########Queremos saber cuales son las palabras mas utilizadas en los titulos por ejemplo

# %% [markdown]
# La información que vamos a analizar es un csv de peliculas llamado movies.csv

# %% [markdown]
# Vamos a proceder con la lectura del dataset. Para lo cual necesitamos esta librerias. En este momento no importamos librerias debido a que ya se hizo al comenzar este archivo.

# %%
#import pandas as pd 
#import matplotlib.pyplot as pyplot 
#import seaborn as sns

# %% [markdown]
# Se creo un dataset del archivo movies.csv. Que lo hicimos en nuestro ETL. Por lo cual no lo vamos a hacer ahora.

# %%
#df_peliculas = pd.read_csv ('..\Proyecto individual Henry\Data\movies_dataset (1).csv')

# %% [markdown]
# Vamos a ver las caracteristicas principales. Nuestro dataset contaba originalmente con registros 45466 y
# 24 columnas

# %% [markdown]
# Cuando se llevo a cabo el ETL se elimino las siguientes columnas: 'video', 'imdb_id', 'adult', 'original_title', 'poster_path' y 'homepage'. Es decir que se eliminaron 6 columnas y tambien se  crearon 3 nuevas columnas 'realease_year','genres_genres' y 'return'.Se eliminaron 120 filas en la limpieza. Quedando con 45346 filas y 21 columnas.

# %%
df_peliculas
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45460                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %%
df_peliculas.to_csv('peliculas.csv', index=False)

# %% [markdown]
# Procedemos a analizar cada una de las columnas

# %%
df_peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45346 entries, 0 to 45465
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4485 non-null   object
#  1   budget                 45346 non-null  int64
#  2   genres                 45346 non-null  object
#  3   id                     45346 non-null  object
#  4   original_language      45346 non-null  object
#  5   overview               44405 non-null  object
#  6   popularity             45346 non-null  object
#  7   production_companies   45346 non-null  object
#  8   production_countries   45346 non-null  object
#  9   release_date           45346 non-null  datetime64[ns]
#  10  revenue                45346 non-null  float64
#  11  runtime                45100 non-null  float64
#  12  spoken_languages       45346 non-null  object
#  13  status                 45266 non-null  object
# ...

# %% [markdown]
# Procedemos a leer los datos

# %% [markdown]
# Voy a realizar un grafico de conteo

# %%
df_peliculas['original_language']= df_peliculas['original_language'].astype(str)
df_peliculas['genres_genres']= df_peliculas['genres_genres'].astype(str)

# %%
df_peliculas['genres_genres']
# Out:
# 0         ['Animation', 'Comedy', 'Family']
# 1        ['Adventure', 'Fantasy', 'Family']
# 2                     ['Romance', 'Comedy']
# 3            ['Comedy', 'Drama', 'Romance']
# 4                                ['Comedy']
#                         ...
# 45460        ['Drama', 'Action', 'Romance']
# 45462                             ['Drama']
# 45463       ['Action', 'Drama', 'Thriller']
# 45464                                    []
# 45465                                    []
# Name: genres_genres, Length: 45346, dtype: object
