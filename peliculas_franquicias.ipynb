# %%
import pandas as pd

# %%
df_peliculas= pd.read_csv('..\Proyecto individual Henry\Data\collection.csv')

# %%
df_peliculas2=pd.read_csv('..\Proyecto individual Henry\Data\peliculas.csv')

# %%
df_peliculas2
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45341                                                NaN         0
# 45342                                                NaN         0
# 45343                                                NaN         0
# 45344                                                NaN         0
# 45345                                                NaN         0
#
#                                    genres      id original_language  \
# 0       ['Animation', 'Comedy', 'Family']     862                en
# ...

# %%
df_peliculas
# Out:
# 0                 Toy Story Collection
# 1            Grumpy Old Men Collection
# 2       Father of the Bride Collection
# 3                James Bond Collection
# 4                     Balto Collection
#                      ...
# 4480           The Carry On Collection
# 4481           The Carry On Collection
# 4482           The Carry On Collection
# 4483    DC Super Hero Girls Collection
# 4484              Red Lotus Collection
# Name: name, Length: 4485, dtype: object

# %%
df_peliculas['name']=df_peliculas['name'].str.replace("'","")

# %%
df_peliculas = df_peliculas['name'].copy()

# %%
df_peliculas2= df_peliculas2['revenue'].copy()

# %%
df_peliculas_franquias = df_peliculas.value_counts().reset_index()
df_peliculas_franquias.columns = ['franquicia', 'cantidad']

# %%
df_peliculas_franquias
# Out:
#                        franquicia  cantidad
# 0                 The Bowery Boys        29
# 1                 Totò Collection        27
# 2           James Bond Collection        26
# 3     ZatôichiThe Blind Swordsman        26
# 4         The Carry On Collection        25
# ...                           ...       ...
# 1690       Glass Tiger collection         1
# 1691  Kathleen Madigan Collection         1
# 1692           The Big Bottom Box         1
# 1693             Joséphine - Saga         1
# 1694         Red Lotus Collection         1
#
# [1695 rows x 2 columns]
